# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaBo1/python_for_DA/blob/main/%D0%92%D1%81%D1%82%D1%83%D0%BF_%D0%B4%D0%BE_%D1%82%D0%B5%D0%BE%D1%80%D1%96%D1%97_%D0%B9%D0%BC%D0%BE%D0%B2%D1%96%D1%80%D0%BD%D0%BE%D1%81%D1%82%D1%96_6_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1 ЗАДАЧА**
#
#  Ви —  продакт менеджер в компанії, яка займається мобільними додатками. Ваша модель монетизації — підписка. У травні 2019 року до вас приєдналося 100 підписників, у червні — 150, у липні — 170. Скільки ці користувачі принесли вам до травня 2021 року включно, якщо щомісячний рівень відтоку становить 5%, а підписка коштує $10?

# %% [markdown]
# 100 - травень 2019
#
# 150 - червень 2019
#
# 170 - липень 2019
#
# Щомісячна вартість підписки: $10
#
# Щомісячний відтік (churn rate): 5%, або 0.05
#
# Період розрахунку: з травня 2019 по травень 2021

# %% [markdown]
# Формула для суми геометричної прогресії:
# ![Monosnap Снимок 2024-10-02 15.18.47.png](data:image/png;base64,...)

# %% [markdown]
# S - загальний дохід від групи підписників,
#
# P - кількість підписників на початку,
#
# r - коефіцієнт відтоку (у нашому випадку 0.95, бо наспуний місяць = поточний місяць х ( 1 - 0.05 ) )
#
# n - кількість місяців (для періоду з травня 2019 по травень 2021 — це 24 місяців)
#
# r в квадраті - коефіцієнт, що відповідає кількості підписників через 𝑛 місяців.

# %% [markdown]
# Дохід від травневих користувачів (100 людей на 24 місяці):
#
# Кількість підписників на початку P = 100
#
# Коефіцієнт відтоку r = 0.95
#
# Кількість місяців n = 24

# %% [markdown]
# ![5472105175297680928.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Отже, дохід до травня 2021 року від травневих користувачів = 14 162

# %% [markdown]
# Дохід від червневих користувачів (150 людей на 23ьмісяці):
#
# Кількість підписників на початку P = 150
#
# Коефіцієнт відтоку r = 0.95
#
# Кількість місяців n = 23 ( на 1 місяць менше ніж у травні)

# %% [markdown]
# ![5472105175297680951.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Отже, дохід від червневих користувачів = 18 891 $

# %% [markdown]
# Дохід від липневих користувачів (170 людей на 22 місяці):
#
# P=170
#
# r=0.95
#
# n=22

# %% [markdown]
# ![5472105175297681022.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Отже, дохід від липневих користувачів = 23 001$

# %% [markdown]
# TOTAL = 14 162 + 18 891 + 23 001 = 56 054 $
# Загальний дохід від цих користувачів до травня 2021 року .

# %% [markdown]
# **2 ЗАДАЧА**
#
# Ви — менеджер по роботі з продуктом в компанії, яка розробляє мобільні ігри. Вашою метою є збільшення кількості активних користувачів. У січні 2020 року у вас було 2000 активних користувачів. З лютого кількість активних користувачів щомісяця зростає на 3%. У той же час, 2% користувачів щомісяця перестають користуватися додатком. Якою буде кількість активних користувачів у грудні 2021 року?

# %% [markdown]
# Приріст користувачів:
#
# Якщо кількість активних користувачів зростає на 3% щомісяця, це означає, що кожного місяця до вже наявних користувачів додається 3% від їхньої кількості.
# Коефіцієнт приросту обчислюється як: ![5472105175297681108.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Відтік користувачів:
#
# Якщо 2% користувачів щомісяця перестають користуватися додатком, це означає, що ми втрачаємо 2% від наявних користувачів.
# Коефіцієнт відтоку обчислюється як: ![5472105175297681109.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Щоб обчислити, як змінюється кількість користувачів з урахуванням як приросту, так і відтоку, потрібно перемножити ці два коефіцієнти:
# **К = 1.03 х 0.98 = 1.0094**
#
# Цей коефіцієнт 𝐾 показує, що в середньому кількість користувачів зростає на 0.94% щомісяця.

# %% [markdown]
# Січень 2020 року: 2000 активних користувачів.
#
# Коефіцієнт зміни 𝐾=1.0094
#
# Кількість місяців 𝑇=24(з лютого 2020 по грудень 2021)
#
# Формула для обчислення кількості користувачів: ![Monosnap Снимок 2024-10-02 21.42.17.png](data:image/png;base64,...)

# %% [markdown]
# 1.Спочатку обчислимо К24.
#
# 2.І обчислимо загальну кількість активних користувачів на кінець грудня 2021 року.
#
# ![5472105175297681142.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Отже, приблизна кількість активних користувачів у грудні 2021 року буде близько 2503

# %% [markdown]
# **3 ЗАДАЧА**
#
# Ви — менеджер з розвитку бізнесу в компанії, що займається створенням платформи для онлайн-курсів. У січні 2021 року ви залучили 500 нових користувачів. У лютому кількість нових користувачів зросла на 50%, у березні — ще на 20%. З квітня приріст нових користувачів стабілізувався на рівні 10% щомісяця. Скільки нових користувачів ви залучили загалом за перше півріччя 2021 року?

# %% [markdown]
# Січень 2021 року: 500 нових користувачів.
#
# Лютий 2021 року: приріст на 50%.
#
# Березень 2021 року: приріст на 20%.
#
# Квітень 2021 року: стабільний приріст на 10% щомісяця.
#
# Травень 2021 року: стабільний приріст на 10%.
#
# Червень 2021 року: стабільний приріст на 10%.

# %% [markdown]
# **Розрахунок нових користувачів по місяцях:**
#
# 1.  Січень = 500 нових користувачів
#
# 2.  Лютий = 500 + ( 500 х 0.50 ) = 500 + 250 = 750
#
# 3.  Березень = 750 + ( 750 х 0.20 ) = 750 + 150 = 900
#
# 4.  Квітень = 900 + ( 900 х 0.10 ) = 900 + 90 = 990
#
# 5.  Травень = 990 + ( 990 х 0.10 ) = 990 + 99 = 1089
#
# 6.  Червень = 1089 + ( 1089 х 0.10 ) = 1089 + 108.9 = 1197.9

# %% [markdown]
# **Тепер ми можемо підрахувати загальну кількість нових користувачів за перше півріччя 2021 року:**
#
# 500 + 750 + 900 + 990 + 1089 + 1197.9 = **5426.9**
