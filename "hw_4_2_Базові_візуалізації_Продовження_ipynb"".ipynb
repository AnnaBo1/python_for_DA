# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaBo1/python_for_DA/blob/main/%22hw_4_2_%D0%91%D0%B0%D0%B7%D0%BE%D0%B2%D1%96_%D0%B2%D1%96%D0%B7%D1%83%D0%B0%D0%BB%D1%96%D0%B7%D0%B0%D1%86%D1%96%D1%97_%D0%9F%D1%80%D0%BE%D0%B4%D0%BE%D0%B2%D0%B6%D0%B5%D0%BD%D0%BD%D1%8F_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнє завдання №1 до модуля 4: Базові візуалізації даних. Продовження

# %% [markdown]
# В цьому домашньому завданні потренуємо створення кількох панелей на одній фігурі для відпрацювання створення складніших візуалізацій з Matplotlib, а також підписи до графіків і створення легенди.
#
# ### Завдання: Візуалізація функцій експоненти, логарифму, і модифікованої синусоїди
#
# **Мета:** Створити фігуру з трьома панелями: на першій показати графік експоненціальної функції, на другій - логарифмічну функцію, а на третій - модифіковану синусоїду.
#
# 1. Імпортуйте необхідні бібліотеки:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Використовуючи фукнціонал `numpy` створіть масив `x` з 400 точок в діапазоні між -2 та 2 і масив `x_positive` в діапазоні між 0.1 і 2 також з 400 точок. Другий масив в нас буде для логарифмічної функції, перший з більш широким діапазоном - для інших функцій.

# %%
x = np.linspace(-2, 2, 400)
x_positive = np.linspace(0.1, 2, 400)

# %% [markdown]
# 3. Тут маємо кілька кроків.
#
#   3.1. Ініціалізуйте фігуру Matplotlib з розміром, достатнім для трьох панелей (рекомендую спробувати експериментально виявити добрий розмір).
#   3.2. На першій панелі візуалізуйте експоненціальну функцію `y = e^x`. Використовуйте відповідну змінну `x`.
#   3.2. На другій панелі покажіть логарифмічну функцію `y = ln(x)`.
#   3.4. На третій панелі покажіть модифіковану синусоїду `y = sin(x) + x`.
#
#   Відобразіть графік.

# %%
#3.1
plt.figure(figsize=(15, 5)) #довжина та висота

#3.2
plt.subplot(1, 3, 1) #1 рядок 3 графіки 1 в якій панелі
y_exp = np.exp(x) #у Python для обчислення експоненціальної функції не можна використовувати запис e^x, оскільки цей запис інтерпретується як число e піднесене до степеня x.
plt.plot(x, y_exp, label='y = e^x')
plt.title("експоненціальна функція")
plt.xlabel('x')
plt.ylabel('y')
plt.legend() # легендa графіка, щоб підпис був видимий (label='y = e^x')

#3.3
plt.subplot(1, 3, 2)
y_log = np.log(x_positive) # обчисленя логарифмічної функції y = ln(x)
plt.plot(x_positive, y_log , 'r', label='y = ln(x)')  # функція, яка створює графік. Вона малює лінійний графік, де:x_positive є масивом значень для осі X.y_log є масивом значень для осі Y
plt.title("логарифмічна функція")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

#3.4
plt.subplot(1, 3, 3)
y = np.sin(x) + x # обчислює значення y, додаючи до синусоїди значення x. Це дає модифіковану синусоїду, де функція sin(𝑥) зміщена на значення x.
plt.plot(x, y , 'g', label='y = sin(x) + x')
plt.title("модифікована синусоїду")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.tight_layout() #щоб роозбило графіки і цифри не були дуууже поруч

# %% [markdown]
# 4. Модифікація і довершення графіку.
#   4.1. Для кожної панелі встановіть назву графіка та підписи до осей х та у (можна так і назвати `x` та формула функції).
#   4.2. Використайте різні кольори для кожного графіка.

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(x, y_exp, label='y = e^x')
plt.title("експоненціальна функція")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(x_positive, y_log , 'r', label='y = ln(x)')
plt.title("логарифмічна функція")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(x, y , 'g', label='y = sin(x) + x')
plt.title("модифікована синусоїду")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.tight_layout()

# %% [markdown]
# 5. А тепер зобразіть ті самі 3 трафіки тих самих кольорів тільки на одному графіку. Визначіть назву кожної з ліній для легенди та обовʼязково відобразіть легенду.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 400)
x_positive = np.linspace(0.1, 2, 400)

y_exp = np.exp(x)
y_log = np.log(x_positive)
y = np.sin(x) + x

plt.figure(figsize=(10, 5))

plt.plot(x, y_exp, label='y = e^x')
plt.plot(x_positive, y_log , 'r--', label='y = ln(x)')
plt.plot(x, y , 'g-.', label='y = sin(x) + x')

plt.title('Графіки функцій')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.savefig('/content/my_figure.png', dpi=100)
plt.close()

# %% [markdown]
# 6. Напишіть код аби зберегти графік з попереднього завдання у файл з назвою `my_figure.png` і виконайте код нижче аби зчитати фігуру з файлу назад в ноутбук аби переконатись, що графік зберігся як треба.

# %%
plt.savefig('/content/my_figure.jpg', dpi=100)
plt.close()

# %%
from IPython.display import Image
Image('my_figure.png')
